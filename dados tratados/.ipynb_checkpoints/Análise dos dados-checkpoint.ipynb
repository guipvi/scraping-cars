# %% [markdown]
# # Gerando e armazenando visualizações

# %% [markdown]
# ## Importando bibliotecas

# %%
# instalando bibliotecas
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\psico\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: scipy>=0.14.0 in c:\users\psico\anaconda3\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: numpy>=1.9.3 in c:\users\psico\anaconda3\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\psico\anaconda3\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: pandas>=0.15.2 in c:\users\psico\anaconda3\lib\site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\psico\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\psico\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\psico\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\psico\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\psico\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\psico\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\psico\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\psico\anaconda3\lib\site-packages (from pandas>=0.15.2->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\psico\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->seaborn) (1.16.0)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 # importando e instalando bibliotecas
#       2 get_ipython().system('pip install seaborn')
# ----> 3 import seaborn as sns
#       4 import pandas as pd
#
# File ~\anaconda3\lib\site-packages\seaborn\__init__.py:6, in <module>
#       3 _orig_rc_params = mpl.rcParams.copy()
#       5 # Import seaborn objects
# ----> 6 from .rcmod import *
#       7 from .utils import *
#       8 from .palettes import *
#
# File ~\anaconda3\lib\site-packages\seaborn\rcmod.py:5, in <module>
#       3 import functools
#       4 import matplotlib as mpl
# ----> 5 from . import palettes, _orig_rc_params
#       8 mpl_ge_150 = LooseVersion(mpl.__version__) >= '1.5.0'
#       9 mpl_ge_2 = LooseVersion(mpl.__version__) >= '2.0'
#
# File ~\anaconda3\lib\site-packages\seaborn\palettes.py:12, in <module>
#       9 from .external.six import string_types
#      10 from .external.six.moves import range
# ---> 12 from .utils import desaturate, set_hls_values, get_color_cycle
#      13 from .colors import xkcd_rgb, crayons
#      16 __all__ = ["color_palette", "hls_palette", "husl_palette", "mpl_palette",
#      17            "dark_palette", "light_palette", "diverging_palette",
#      18            "blend_palette", "xkcd_palette", "crayon_palette",
#      19            "cubehelix_palette", "set_color_codes"]
#
# File ~\anaconda3\lib\site-packages\seaborn\utils.py:7, in <module>
#       4 import os
#       6 import numpy as np
# ----> 7 from scipy import stats
#       8 import pandas as pd
#       9 import matplotlib as mpl
#
# File ~\anaconda3\lib\site-packages\scipy\stats\__init__.py:441, in <module>
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     438
#     439 """
# --> 441 from .stats import *
#     442 from .distributions import *
#     443 from .morestats import *
#
# File ~\anaconda3\lib\site-packages\scipy\stats\stats.py:43, in <module>
#      41 import scipy.special as special
#      42 from scipy import linalg
# ---> 43 from . import distributions
#      44 from . import mstats_basic
#      45 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#      46                                    siegelslopes)
#
# File ~\anaconda3\lib\site-packages\scipy\stats\distributions.py:8, in <module>
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
# ----> 8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#      10 from . import _continuous_distns
#      11 from . import _discrete_distns
#
# File ~\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:24, in <module>
#      20 from scipy.special import (comb, chndtr, entr, xlogy, ive)
#      22 # for root finding for continuous distribution ppf, and max likelihood
#      23 # estimation
# ---> 24 from scipy import optimize
#      26 # for functions of continuous distributions (e.g. moments, entropy, cdf)
#      27 from scipy import integrate
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\__init__.py:400, in <module>
#       1 """
#       2 =====================================================
#       3 Optimization and root finding (:mod:`scipy.optimize`)
#    (...)
#     397 :mod:`Additional information on the nonlinear solvers <scipy.optimize.nonlin>`
#     398 """
# --> 400 from .optimize import *
#     401 from ._minimize import *
#     402 from ._root import *
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py:36, in <module>
#      32 import numpy as np
#      33 from .linesearch import (line_search_wolfe1, line_search_wolfe2,
#      34                          line_search_wolfe2 as line_search,
#      35                          LineSearchWarning)
# ---> 36 from ._numdiff import approx_derivative
#      37 from scipy._lib._util import getfullargspec_no_self as _getfullargspec
#      38 from scipy._lib._util import MapWrapper
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py:6, in <module>
#       3 import numpy as np
#       4 from numpy.linalg import norm
# ----> 6 from scipy.sparse.linalg import LinearOperator
#       7 from ..sparse import issparse, csc_matrix, csr_matrix, coo_matrix, find
#       8 from ._group_columns import group_dense, group_sparse
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\linalg\__init__.py:114, in <module>
#     112 from .dsolve import *
#     113 from .interface import *
# --> 114 from .eigen import *
#     115 from .matfuncs import *
#     116 from ._onenormest import *
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\__init__.py:9, in <module>
#       1 """
#       2 Sparse Eigenvalue Solvers
#       3 -------------------------
#    (...)
#       7
#       8 """
# ----> 9 from .arpack import *
#      10 from .lobpcg import *
#      12 __all__ = [s for s in dir() if not s.startswith('_')]
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\__init__.py:20, in <module>
#       1 """
#       2 Eigenvalue solver using iterative methods.
#       3
#    (...)
#      18
#      19 """
# ---> 20 from .arpack import *
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py:42, in <module>
#      38 __docformat__ = "restructuredtext en"
#      40 __all__ = ['eigs', 'eigsh', 'svds', 'ArpackError', 'ArpackNoConvergence']
# ---> 42 from . import _arpack
#      43 arpack_int = _arpack.timing.nbx.dtype
#      45 import numpy as np
#
# ImportError: DLL load failed while importing _arpack: Não foi possível encontrar o procedimento especificado.

# %%
import seaborn as sns
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 import seaborn as sns
#       2 import pandas as pd
#
# File ~\anaconda3\lib\site-packages\seaborn\__init__.py:6, in <module>
#       3 _orig_rc_params = mpl.rcParams.copy()
#       5 # Import seaborn objects
# ----> 6 from .rcmod import *
#       7 from .utils import *
#       8 from .palettes import *
#
# File ~\anaconda3\lib\site-packages\seaborn\rcmod.py:5, in <module>
#       3 import functools
#       4 import matplotlib as mpl
# ----> 5 from . import palettes, _orig_rc_params
#       8 mpl_ge_150 = LooseVersion(mpl.__version__) >= '1.5.0'
#       9 mpl_ge_2 = LooseVersion(mpl.__version__) >= '2.0'
#
# File ~\anaconda3\lib\site-packages\seaborn\palettes.py:12, in <module>
#       9 from .external.six import string_types
#      10 from .external.six.moves import range
# ---> 12 from .utils import desaturate, set_hls_values, get_color_cycle
#      13 from .colors import xkcd_rgb, crayons
#      16 __all__ = ["color_palette", "hls_palette", "husl_palette", "mpl_palette",
#      17            "dark_palette", "light_palette", "diverging_palette",
#      18            "blend_palette", "xkcd_palette", "crayon_palette",
#      19            "cubehelix_palette", "set_color_codes"]
#
# File ~\anaconda3\lib\site-packages\seaborn\utils.py:7, in <module>
#       4 import os
#       6 import numpy as np
# ----> 7 from scipy import stats
#       8 import pandas as pd
#       9 import matplotlib as mpl
#
# File ~\anaconda3\lib\site-packages\scipy\stats\__init__.py:441, in <module>
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     438
#     439 """
# --> 441 from .stats import *
#     442 from .distributions import *
#     443 from .morestats import *
#
# File ~\anaconda3\lib\site-packages\scipy\stats\stats.py:43, in <module>
#      41 import scipy.special as special
#      42 from scipy import linalg
# ---> 43 from . import distributions
#      44 from . import mstats_basic
#      45 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#      46                                    siegelslopes)
#
# File ~\anaconda3\lib\site-packages\scipy\stats\distributions.py:8, in <module>
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
# ----> 8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#      10 from . import _continuous_distns
#      11 from . import _discrete_distns
#
# File ~\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:24, in <module>
#      20 from scipy.special import (comb, chndtr, entr, xlogy, ive)
#      22 # for root finding for continuous distribution ppf, and max likelihood
#      23 # estimation
# ---> 24 from scipy import optimize
#      26 # for functions of continuous distributions (e.g. moments, entropy, cdf)
#      27 from scipy import integrate
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\__init__.py:400, in <module>
#       1 """
#       2 =====================================================
#       3 Optimization and root finding (:mod:`scipy.optimize`)
#    (...)
#     397 :mod:`Additional information on the nonlinear solvers <scipy.optimize.nonlin>`
#     398 """
# --> 400 from .optimize import *
#     401 from ._minimize import *
#     402 from ._root import *
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py:36, in <module>
#      32 import numpy as np
#      33 from .linesearch import (line_search_wolfe1, line_search_wolfe2,
#      34                          line_search_wolfe2 as line_search,
#      35                          LineSearchWarning)
# ---> 36 from ._numdiff import approx_derivative
#      37 from scipy._lib._util import getfullargspec_no_self as _getfullargspec
#      38 from scipy._lib._util import MapWrapper
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py:6, in <module>
#       3 import numpy as np
#       4 from numpy.linalg import norm
# ----> 6 from scipy.sparse.linalg import LinearOperator
#       7 from ..sparse import issparse, csc_matrix, csr_matrix, coo_matrix, find
#       8 from ._group_columns import group_dense, group_sparse
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\linalg\__init__.py:114, in <module>
#     112 from .dsolve import *
#     113 from .interface import *
# --> 114 from .eigen import *
#     115 from .matfuncs import *
#     116 from ._onenormest import *
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\__init__.py:9, in <module>
#       1 """
#       2 Sparse Eigenvalue Solvers
#       3 -------------------------
#    (...)
#       7
#       8 """
# ----> 9 from .arpack import *
#      10 from .lobpcg import *
#      12 __all__ = [s for s in dir() if not s.startswith('_')]
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\__init__.py:20, in <module>
#       1 """
#       2 Eigenvalue solver using iterative methods.
#       3
#    (...)
#      18
#      19 """
# ---> 20 from .arpack import *
#
# File ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py:42, in <module>
#      38 __docformat__ = "restructuredtext en"
#      40 __all__ = ['eigs', 'eigsh', 'svds', 'ArpackError', 'ArpackNoConvergence']
# ---> 42 from . import _arpack
#      43 arpack_int = _arpack.timing.nbx.dtype
#      45 import numpy as np
#
# ImportError: DLL load failed while importing _arpack: Não foi possível encontrar o procedimento especificado.

# %% [markdown]
# ## Finalizando tratamento dos dados

# %%
# importando dados
dados_carros = pd.read_csv('dados_carros04-05-2022.csv', sep = ';')

# removendo duplicatas
dados_carros.drop_duplicates(inplace=True)
# definindo o index
dados_carros.set_index('link', inplace=True)

# valores-str para valores-int
valores = []
for valor in dados_carros['valor']:
    try:
        valor = (int(valor))
        valores.append(valor)
    except Exception:
        valor = valor.split("['")[1].split("']")[0]
        valor = int(valor)
        valores.append(valor)
dados_carros['valor'] = valores

# corrigindo inconsistências
dados_carros.drop(dados_carros[dados_carros['ano_fabricacao'] == 'Campinas'].index, inplace=True)

# anos-str para anos-int
anosf = []
for ano in dados_carros['ano_fabricacao']:
    try:
        ano = int(ano)
        anosf.append(ano)
    except Exception:
        print('ano')
dados_carros['ano_fabricacao'] = anosf
anosm = []
for ano in dados_carros['ano_modelo']:
    try:
        ano = int(ano)
        anosm.append(ano)
    except Exception:
        print('ano')
dados_carros['ano_modelo'] = anosm

# removendo colunas duplicatas
links_valores.drop(['ano'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 # importando dados
# ----> 2 dados_carros = pd.read_csv('dados_carros04-05-2022.csv', sep = ';')
#       4 # removendo duplicatas
#       5 dados_carros.drop_duplicates(inplace=True)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Analisando dados_carros

# %%
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\psico\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\psico\AppData\Local\Temp\ipykernel_16236\2351219987.py", line 1, in <cell line: 1>
#     import seaborn as sns
#   File "C:\Users\psico\anaconda3\lib\site-packages\seaborn\__init__.py", line 6, in <module>
#     from .rcmod import *
#   File "C:\Users\psico\anaconda3\lib\site-packages\seaborn\rcmod.py", line 5, in <module>
#     from . import palettes, _orig_rc_params
#   File "C:\Users\psico\anaconda3\lib\site-packages\seaborn\palettes.py", line 12, in <module>
#     from .utils import desaturate, set_hls_values, get_color_cycle
#   File "C:\Users\psico\anaconda3\lib\site-packages\seaborn\utils.py", line 7, in <module>
#     from scipy import stats
#   File "C:\Users\psico\anaconda3\lib\site-packages\scipy\stats\__init__.py", line 441, in <module>
#     from .stats import *
#   File "C:\Users\psico\anaconda3\lib\site-packages\scipy\stats\stats.py", line 43, in <module>
#     from . import distributions
#   File "C:\Users\psico\anaconda3\lib\site-packages\scipy\stats\distributions.py", line 8, in <module>
#     from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#   File "C:\Users\psico\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py", line 24, in <module>
#     from scipy import optimize
#   File "C:\Users\psico\anaconda3\lib\site-packages\scipy\optimize\__init__.py", line 400, in <module>
#     from .optimize import *
#   File "C:\Users\psico\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 36, in <module>
#     from ._numdiff import approx_derivative
#   File "C:\Users\psico\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py", line 6, in <module>
#     from scipy.sparse.linalg import LinearOperator
#   File "C:\Users\psico\anaconda3\lib\site-packages\scipy\sparse\linalg\__init__.py", line 114, in <module>
#     from .eigen import *
#   File "C:\Users\psico\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\__init__.py", line 9, in <module>
#     from .arpack import *
#   File "C:\Users\psico\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\__init__.py", line 20, in <module>
#     from .arpack import *
#   File "C:\Users\psico\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py", line 42, in <module>
#     from . import _arpack
# ImportError: DLL load failed while importing _arpack: Não foi possível encontrar o procedimento especificado.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\psico\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 1982, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\psico\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\psico\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\psico\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\psico\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "C:\Users\psico\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "C:\Users\psico\anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\psico\anaconda3\lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "C:\Users\psico\anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\psico\anaconda3\lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "C:\Users\psico\anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\psico\anaconda3\lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#   File "C:\Users\psico\anaconda3\lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
sns.lineplot(x='ano_modelo', y='valor', dataset=dados_carros)
